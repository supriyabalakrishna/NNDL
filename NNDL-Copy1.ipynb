# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %%
x = np.random.rand(1000,20)

# %%
y = np.random.randint(0,2,size=(1000,))

# %%
model = keras.Sequential([
    layers.Dense(64,activation = "relu" , input_shape = (20,)),
    layers.Dense(32,activation = "relu"),
    layers.Dense(1, activation = "sigmoid")])
# Out:
# C:\Users\Supriya Balakrishna\anaconda3\envs\tfclean\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer = "adam",
    loss = "binary_crossentropy",
    metrics = ["accuracy"])

# %%
history = model.fit(
    x,
    y,
    epochs = 20,
    batch_size = 32,
    validation_split = 0.2)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4787 - loss: 0.6984 - val_accuracy: 0.5100 - val_loss: 0.6912
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5138 - loss: 0.6932 - val_accuracy: 0.5450 - val_loss: 0.6910
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4988 - loss: 0.6927 - val_accuracy: 0.5600 - val_loss: 0.6911
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5713 - loss: 0.6878 - val_accuracy: 0.4900 - val_loss: 0.6932
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5337 - loss: 0.6868 - val_accuracy: 0.5350 - val_loss: 0.6926
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5600 - loss: 0.6842 - val_accuracy: 0.4500 - val_loss: 0.6960
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5950 - loss: 0.6811 - val_accuracy: 0.4700 - val_loss: 0.6947
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5888 - loss: 0.6791 - val_accuracy: 0.4700 - val_loss: 0.6959
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6162 - loss: 0.6758 - val_accuracy: 0.4800 - val_loss: 0.6990
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6125 - loss: 0.6737 - val_accuracy: 0.5150 - val_loss: 0.6967
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.5975 - loss: 0.6714 - val_accuracy: 0.5100 - val_loss: 0.7011
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6137 - loss: 0.6698 - val_accuracy: 0.5150 - val_loss: 0.6993
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6125 - loss: 0.6668 - val_accuracy: 0.4700 - val_loss: 0.7033
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6137 - loss: 0.6632 - val_accuracy: 0.4900 - val_loss: 0.7054
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6275 - loss: 0.6608 - val_accuracy: 0.4850 - val_loss: 0.7059
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6300 - loss: 0.6574 - val_accuracy: 0.4900 - val_loss: 0.7108
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6288 - loss: 0.6542 - val_accuracy: 0.4700 - val_loss: 0.7087
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6400 - loss: 0.6498 - val_accuracy: 0.4900 - val_loss: 0.7112
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6425 - loss: 0.6491 - val_accuracy: 0.5050 - val_loss: 0.7121
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6350 - loss: 0.6456 - val_accuracy: 0.5150 - val_loss: 0.7136

# %%
history = model.fit(
    x_train,
    y_train,
    epochs = 10,
    validation_split = 0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9637 - loss: 0.1196 - val_accuracy: 0.9654 - val_loss: 0.1165
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9663 - loss: 0.1139 - val_accuracy: 0.9647 - val_loss: 0.1192
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9671 - loss: 0.1115 - val_accuracy: 0.9631 - val_loss: 0.1243
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9675 - loss: 0.1104 - val_accuracy: 0.9615 - val_loss: 0.1251
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9677 - loss: 0.1082 - val_accuracy: 0.9611 - val_loss: 0.1308
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9684 - loss: 0.1069 - val_accuracy: 0.9612 - val_loss: 0.1313
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9685 - loss: 0.1055 - val_accuracy: 0.9611 - val_loss: 0.1311
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 21s 10ms/step - accuracy: 0.9691 - loss: 0.1039 - val_accuracy: 0.9592 - val_loss: 0.1349
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9702 - loss: 0.1028 - val_accuracy: 0.9595 - val_loss: 0.1382
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9706 - loss: 0.1016 - val_accuracy: 0.9591 - val_loss: 0.1355

# %%
loss,accuracy = model.evaluate(x,y)
print("accuracy : ", accuracy)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6350 - loss: 0.6520
# accuracy :  0.6349999904632568

# %%
predictions = model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
import matplotlib.pyplot as plt

# %%
print("hello")
# Out:
# hello

# %%
(x_train , y_train),(x_test,y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
model = Sequential([
    Flatten(input_shape =(28,28)),
    Dense(16,activation='sigmoid',input_shape=(784,)),
    Dense(10,activation = 'softmax')
])
# Out:
# C:\Users\Supriya Balakrishna\anaconda3\envs\tfclean\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(
    optimizer = Adam(learning_rate = 0.01),
    loss =  "sparse_categorical_crossentropy",
    metrics = ['accuracy'])

# %%
history = model.fit(
    x_train,
    y_train,
    epochs = 10,
    validation_split = 0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9413 - loss: 0.1901 - val_accuracy: 0.9445 - val_loss: 0.1947
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9448 - loss: 0.1806 - val_accuracy: 0.9417 - val_loss: 0.1997
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9465 - loss: 0.1752 - val_accuracy: 0.9406 - val_loss: 0.1980
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9467 - loss: 0.1693 - val_accuracy: 0.9410 - val_loss: 0.2034
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9481 - loss: 0.1646 - val_accuracy: 0.9425 - val_loss: 0.2067
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9515 - loss: 0.1608 - val_accuracy: 0.9326 - val_loss: 0.2363
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9500 - loss: 0.1619 - val_accuracy: 0.9408 - val_loss: 0.2127
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.9521 - loss: 0.1525 - val_accuracy: 0.9385 - val_loss: 0.2166
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9528 - loss: 0.1537 - val_accuracy: 0.9362 - val_loss: 0.2246
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9545 - loss: 0.1479 - val_accuracy: 0.9423 - val_loss: 0.2032

# %%
model.fit(x_train,y_train,epochs = 5 , batch_size = 32)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9500 - loss: 0.1633
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9525 - loss: 0.1568
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.9523 - loss: 0.1545
# Epoch 4/5
# 1682/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9535 - loss: 0.1500

# %%
model.fit(x_train,y_train,epochs = 10 , batch_size = 64)
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9574 - loss: 0.1466
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9579 - loss: 0.1451
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9580 - loss: 0.1431
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9590 - loss: 0.1412
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9591 - loss: 0.1389
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9598 - loss: 0.1366
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9606 - loss: 0.1347
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9607 - loss: 0.1328
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9614 - loss: 0.1310
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9620 - loss: 0.1290

# %%
model.fit(x_train,y_train,epochs = 15 , batch_size = 128)
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9636 - loss: 0.1244
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9637 - loss: 0.1240
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9639 - loss: 0.1230
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9643 - loss: 0.1223
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9643 - loss: 0.1214
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9651 - loss: 0.1200
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9647 - loss: 0.1197
# Epoch 8/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9650 - loss: 0.1187
# Epoch 9/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9654 - loss: 0.1172
# Epoch 10/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9658 - loss: 0.1166
# Epoch 11/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9655 - loss: 0.1155
# Epoch 12/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9664 - loss: 0.1145
# Epoch 13/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9666 - loss: 0.1136
# Epoch 14/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9665 - loss: 0.1128
# Epoch 15/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9672 - loss: 0.1121

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9487 - loss: 0.1796
# [0.1795748621225357, 0.9487000107765198]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],label = 'Train Accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuaracy')
plt.legend()

# %%
plt.subplot(1,2,1)
plt.plot(history.history['loss'],label = 'Train loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()

# %%
model = keras.Sequential([
    layers.Dense(2,activation ='sigmoid',input_shape = (784,)),
    layers.Dense(10,activation = 'softmax')])

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(
    optimizer = Adam(learning_rate = 0.1),
    loss = "sparse_categorical_crossentropy",
    metrics = ['accuracy']
)

# %%
epoch = 5,10,15
batchsize = 32,64,128

# %%
model.fit(x_train,y_train,epochs = 10 , batch_size = 64)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 model.fit(x_train,y_train,epochs = 10 , batch_size = 64)
#
# File ~\anaconda3\envs\tfclean\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\envs\tfclean\lib\site-packages\keras\src\models\functional.py:276, in Functional._adjust_input_rank(self, flat_inputs)
#     274             adjusted.append(ops.expand_dims(x, axis=-1))
#     275             continue
# --> 276     raise ValueError(
#     277         f"Invalid input shape for input {x}. Expected shape "
#     278         f"{ref_shape}, but input has incompatible shape {x.shape}"
#     279     )
#     280 # Add back metadata.
#     281 for i in range(len(flat_inputs)):
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Invalid input shape for input Tensor("data:0", shape=(None, 28, 28), dtype=float32). Expected shape (None, 784), but input has incompatible shape (None, 28, 28)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(None, 28, 28), dtype=float32)
#   • training=True
#   • mask=None
#   • kwargs=<class 'inspect._empty'>
